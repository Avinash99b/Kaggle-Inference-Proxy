# %%
import os
TARGET_MODEL_REPO="Qwen/Qwen3-0.6B-GGUF"
FILE_NAME="Qwen3-0.6B-Q8_0.gguf"
PROXY_URL = "http://localhost:8000"
WORKER_ID = "worker2"
WORKER_SECRET = "change-me-worker-secret"
HF_TOKEN = "{config.hf_token or ''}"
os.environ.update({
    "TARGET_MODEL_REPO": TARGET_MODEL_REPO,
    "PROXY_URL": PROXY_URL,
    "FILE_NAME":FILE_NAME,
    "WORKER_ID": WORKER_ID,
    "WORKER_SECRET": WORKER_SECRET,
    "HUGGINGFACE_TOKEN": HF_TOKEN,
})

# %%
# !python /home/avinash/Projects/Proxy-Inference/Proxy-Client/inferece_client.py
# Out:
# [worker] No config found at '/home/avinash/Projects/Proxy-Inference/Proxy-Client/inference_server_config.json'. Created a default config there.
# 2026-07-17 19:24:35,586 [INFO] worker: Starting inference server worker 'worker2' -> proxy http://localhost:8000 (target model: Qwen/Qwen3-0.6B-GGUF/Qwen3-0.6B-Q8_0.gguf)
# 2026-07-17 19:24:35,610 [INFO] worker: Detected 1 GPU(s).
# ggml_cuda_init: found 1 CUDA devices (Total VRAM: 3770 MiB):
#   Device 0: NVIDIA GeForce RTX 3050 Laptop GPU, compute capability 8.6, VMM: yes, VRAM: 3770 MiB
# 2026-07-17 19:24:35,947 [INFO] worker: llama-cpp-python already importable with CUDA support.
# 2026-07-17 19:24:35,949 [INFO] worker: Resolving 'Qwen3-0.6B-Q8_0.gguf' from Qwen/Qwen3-0.6B-GGUF (attempt 1/4)...
# 2026-07-17 19:24:36,286 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/Qwen/Qwen3-0.6B-GGUF/resolve/main/Qwen3-0.6B-Q8_0.gguf "HTTP/1.1 302 Found"
# ...
